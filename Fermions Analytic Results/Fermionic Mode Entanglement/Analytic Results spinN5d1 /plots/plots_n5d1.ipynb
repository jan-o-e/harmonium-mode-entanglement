# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec, rc
import pandas as pd

# %%
file_name_list = ['imode0pos','ipmode0pos', 'inmode0pos', 'emode0pos', 'epmode0pos', 'enmode0pos', 'imode0neg','inmode0neg', 'ipmode0neg', 'emode0neg', 'epmode0neg', 'enmode0neg']

mode0data=[]

for file in file_name_list:
    mode0data.append(pd.read_csv('/Users/janoleernst/Desktop/DPhil/Code/GIT-Mode-Entanglement/Analytic Results spinN4d1_1mode/data_ferm_4d1_mode/{}'.format(file)).values)
   
print(len(mode0data))
# Out:
# 12

# %%
imode0pos=mode0data[0]
ipmode0pos = mode0data[1]
inmode0pos = mode0data[2]
emode0pos=mode0data[3]
epmode0pos = mode0data[4]
enmode0pos = mode0data[5]

imode0neg=mode0data[6]
ipmode0neg = mode0data[7]
inmode0neg = mode0data[8]
emode0neg=mode0data[9]
epmode0neg = mode0data[10]
enmode0neg = mode0data[11]

emax = 1.386
imax = 2*emax

kappalist_neg = np.linspace(-0.99,1, num=len(imode0neg))
kappalist_pos = np.linspace(1,6, num=len(imode0pos))


rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)

fig = plt.figure(figsize=(10,8))
gs = fig.add_gridspec(2, 2, hspace=0, wspace=0,)
(ax1, ax2), (ax3, ax4) = gs.subplots(sharex='col', sharey='row')
ax1.plot(kappalist_neg, emode0neg, label='$E$', color='black', linewidth=2.5)
ax1.plot(kappalist_neg, imode0neg, label='$I$', color='grey', linewidth=2.5)
ax1.plot(kappalist_neg, ipmode0neg, label='$I^{P}$', color='grey', linestyle='dashed', linewidth=2)
ax1.plot(kappalist_neg, inmode0neg, label='$I^{N}$', color='grey', linestyle='dotted', linewidth=2)
ax1.tick_params(axis='y', width=1, labelsize=20)
ax1.legend(loc = 'upper right', fontsize=22)
ax1.set_ylabel('Correlation Measure', fontsize=22)
ax3.set_xlabel('Coupling strength / $\kappa$', fontsize=22)
ax3.set_ylabel('Correlation Measure', fontsize=22)
ax4.set_xlabel('Coupling strength / $\kappa$', fontsize=22)
ax2.plot(kappalist_pos, emode0pos, label='$E$', color='black', linewidth=2.5)
ax2.plot(kappalist_pos, imode0pos, label='$I$', color='grey', linewidth=2.5)
ax2.plot(kappalist_pos, ipmode0pos, label='$I^{P}$', color='grey', linestyle='dashed', linewidth=2)
ax2.plot(kappalist_pos, inmode0pos, label='$I^{N}$', color='grey', linestyle='dotted', linewidth=2)
#ax2.hlines(emax, xmin=1, xmax = 100000, color='red', linestyle='dashdot', linewidth=2)
#ax2.hlines(imax, xmin=1, xmax = 100000, color='red', linestyle='dashdot', linewidth=2)
ax2.set_xticks([1,2,3,4,5,6], labels=['$1$', '$10$', '$100$', '$1000$', '$10000$', '$100000$'])
ax2.tick_params(axis='x', width=1, labelsize=20)
ax3.tick_params(axis='y', width=1, labelsize=20)


ax3.plot(kappalist_neg, emode0neg, label='$E$', color='black', linewidth=2.5)
ax3.plot(kappalist_neg, imode0neg, label='$I$', color='grey', linewidth=2.5)
ax3.plot(kappalist_neg, epmode0neg, label='$E^{P}$', color='grey', linestyle='dashed', linewidth=2)
ax3.plot(kappalist_neg, enmode0neg, label='$E^{N}$', color='grey', linestyle='dotted', linewidth=2)
ax3.set_xticks([-1,-0.5,0,0.5,1])
ax3.tick_params(axis='x', width=1, labelsize=20)
ax3.legend(loc = 'upper right', fontsize=22)
ax4.plot(kappalist_pos, emode0pos, label='$E$', color='black', linewidth=2.5)
ax4.plot(kappalist_pos, imode0pos, label='$I$', color='grey', linewidth=2.5)
ax4.plot(kappalist_pos, epmode0pos, label='$E^{P}$', color='grey', linestyle='dashed', linewidth=2)
ax4.plot(kappalist_pos, enmode0pos, label='E^{N}$', color='grey', linestyle='dotted', linewidth=2)
ax4.tick_params(axis='x', width=1, labelsize=20)

fig.savefig('ferm_spin_n4d1_m0.pdf')

# %%
file_name_list = ['imode2pos','ipmode2pos', 'inmode2pos', 'emode2pos', 'epmode2pos', 'enmode2pos', 'imode2neg','inmode2neg', 'ipmode2neg', 'emode2neg', 'epmode2neg', 'enmode2neg']

mode2data=[]

for file in file_name_list:
    mode2data.append(pd.read_csv('/Users/janoleernst/Desktop/DPhil/Code/GIT-Mode-Entanglement/Analytic Results spinN4d1_1mode/data_ferm_4d1_mode/{}'.format(file)).values)
   
print(len(mode2data))
# Out:
# 12

# %%
imode2pos=mode2data[0]
ipmode2pos = mode2data[1]
inmode2pos = mode2data[2]
emode2pos=mode2data[3]
epmode2pos = mode2data[4]
enmode2pos = mode2data[5]

imode2neg=mode2data[6]
ipmode2neg = mode2data[7]
inmode2neg = mode2data[8]
emode2neg=mode2data[9]
epmode2neg = mode2data[10]
enmode2neg = mode2data[11]

kappalist_neg = np.linspace(-0.99,1, num=len(imode2neg))
kappalist_pos = np.linspace(1,6, num=len(imode2pos))

rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)

fig = plt.figure(figsize=(10,8))
gs = fig.add_gridspec(2, 2, hspace=0, wspace=0,)
(ax1, ax2), (ax3, ax4) = gs.subplots(sharex='col', sharey='row')
ax1.plot(kappalist_neg, emode2neg, label='$E$', color='black', linewidth=2.5)
ax1.plot(kappalist_neg, imode2neg, label='$I$', color='grey', linewidth=2.5)
ax1.plot(kappalist_neg, ipmode2neg, label='$I^{P}$', color='grey', linestyle='dashed', linewidth=2)
ax1.plot(kappalist_neg, inmode2neg, label='$I^{N}$', color='grey', linestyle='dotted', linewidth=2)
ax1.tick_params(axis='y', width=1, labelsize=20)
ax1.legend(loc = 'upper right', fontsize=22)
ax1.set_ylabel('Correlation Measure', fontsize=22)
ax3.set_xlabel('Coupling strength / $\kappa$', fontsize=22)
ax3.set_ylabel('Correlation Measure', fontsize=22)
ax4.set_xlabel('Coupling strength / $\kappa$', fontsize=22)
ax2.plot(kappalist_pos, emode2pos, label='$E$', color='black', linewidth=2.5)
ax2.plot(kappalist_pos, imode2pos, label='$I$', color='grey', linewidth=2.5)
ax2.plot(kappalist_pos, ipmode2pos, label='$I^{P}$', color='grey', linestyle='dashed', linewidth=2)
ax2.plot(kappalist_pos, inmode2pos, label='$I^{N}$', color='grey', linestyle='dotted', linewidth=2)
ax2.set_xticks([1,2,3,4,5,6], labels=['$1$', '$10$', '$100$', '$1000$', '$10000$', '$100000$'])
ax2.tick_params(axis='x', width=1, labelsize=20)
ax3.tick_params(axis='y', width=1, labelsize=20)


ax3.plot(kappalist_neg, emode2neg, label='$E$', color='black', linewidth=2.5)
ax3.plot(kappalist_neg, imode2neg, label='$I$', color='grey', linewidth=2.5)
ax3.plot(kappalist_neg, epmode2neg, label='$E^{P}$', color='grey', linestyle='dashed', linewidth=2)
ax3.plot(kappalist_neg, enmode2neg, label='$E^{N}$', color='grey', linestyle='dotted', linewidth=2)
ax3.set_xticks([-1,-0.5,0,0.5,1])
ax3.tick_params(axis='x', width=1, labelsize=20)
ax3.legend(loc = 'upper right', fontsize=22)
ax4.plot(kappalist_pos, emode2pos, label='$E$', color='black', linewidth=2.5)
ax4.plot(kappalist_pos, imode2pos, label='$I$', color='grey', linewidth=2.5)
ax4.plot(kappalist_pos, epmode2pos, label='$E^{P}$', color='grey', linestyle='dashed', linewidth=2)
ax4.plot(kappalist_pos, enmode2pos, label='E^{N}$', color='grey', linestyle='dotted', linewidth=2)
ax4.tick_params(axis='x', width=1, labelsize=20)

fig.savefig('ferm_spin_n4d1_m2.pdf')

# %%
file_name_list_ep = ['epemode0 neg','epemode1 neg', 'epemode2 neg', 'epemode3 neg', 'epemode4 neg', 'epemode6 neg', 'epemode8 neg', 'epemode0 pos','epemode1 pos', 'epemode2 pos', 'epemode3 pos', 'epemode4 pos', 'epemode6 pos', 'epemode8 pos']
file_name_list_en = ['enemode0 neg','enemode1 neg', 'enemode2 neg', 'enemode3 neg', 'enemode4 neg', 'enemode6 neg', 'enemode8 neg', 'enemode0 pos','enemode1 pos', 'enemode2 pos', 'enemode3 pos', 'enemode4 pos', 'enemode6 pos', 'enemode8 pos']

epdata5=[]
endata5 = []
epdata4=[]
endata4 = []
epdata3=[]
endata3 = []

for file in file_name_list_ep:
    epdata5.append(pd.read_csv('/Users/janoleernst/Desktop/DPhil/Code/GIT-Mode-Entanglement/Analytic Results spinN5d1_1mode /data_ferm_5d1_mode/{}'.format(file)).values)

for file in file_name_list_en:
    endata5.append(pd.read_csv('/Users/janoleernst/Desktop/DPhil/Code/GIT-Mode-Entanglement/Analytic Results spinN5d1_1mode /data_ferm_5d1_mode/{}'.format(file)).values)


for file in file_name_list_ep:
    epdata4.append(pd.read_csv('/Users/janoleernst/Desktop/DPhil/Code/GIT-Mode-Entanglement/Analytic Results spinN4d1_1mode/data_ferm_4d1_mode/{}'.format(file)).values)

for file in file_name_list_en:
    endata4.append(pd.read_csv('/Users/janoleernst/Desktop/DPhil/Code/GIT-Mode-Entanglement/Analytic Results spinN4d1_1mode/data_ferm_4d1_mode/{}'.format(file)).values)


for file in file_name_list_ep:
    epdata3.append(pd.read_csv('/Users/janoleernst/Desktop/DPhil/Code/GIT-Mode-Entanglement/Analytic Results spinN3d1_1mode/data_ferm_3d1_mode/k0split2.0/{}'.format(file)).values)

for file in file_name_list_en:
    endata3.append(pd.read_csv('/Users/janoleernst/Desktop/DPhil/Code/GIT-Mode-Entanglement/Analytic Results spinN3d1_1mode/data_ferm_3d1_mode/k0split2.0/{}'.format(file)).values)

# %%
epmode0neg_n5= epdata5[0]
epmode1neg_n5 = epdata5[1]
epmode2neg_n5 = epdata5[2]
epmode3neg_n5 =epdata5[3]
epmode4neg_n5 = epdata5[4]

epmode0pos_n5= epdata5[7]
epmode1pos_n5 = epdata5[8]
epmode2pos_n5 = epdata5[9]
epmode3pos_n5 =epdata5[10]
epmode4pos_n5 = epdata5[11]

enmode0neg_n5= endata5[0]
enmode1neg_n5 = endata5[1]
enmode2neg_n5 = endata5[2]
enmode3neg_n5 =endata5[3]
enmode4neg_n5 = endata5[4]

enmode0pos_n5= endata5[7]
enmode1pos_n5 = endata5[8]
enmode2pos_n5 = endata5[9]
enmode3pos_n5 =endata5[10]
enmode4pos_n5 = endata5[11]

epmode0neg_n4= epdata4[0]
epmode1neg_n4 = epdata4[1]
epmode2neg_n4 = epdata4[2]
epmode3neg_n4 =epdata4[3]
epmode4neg_n4 = epdata4[4]

epmode0pos_n4= epdata4[7]
epmode1pos_n4 = epdata4[8]
epmode2pos_n4 = epdata4[9]
epmode3pos_n4 =epdata4[10]
epmode4pos_n4 = epdata4[11]

enmode0neg_n4= endata4[0]
enmode1neg_n4 = endata4[1]
enmode2neg_n4 = endata4[2]
enmode3neg_n4 =endata4[3]
enmode4neg_n4 = endata4[4]

enmode0pos_n4= endata4[7]
enmode1pos_n4 = endata4[8]
enmode2pos_n4 = endata4[9]
enmode3pos_n4 =endata4[10]
enmode4pos_n4 = endata4[11]

epmode0neg_n3= epdata3[0]
epmode1neg_n3 = epdata3[1]
epmode2neg_n3 = epdata3[2]
epmode3neg_n3 =epdata3[3]
epmode4neg_n3 = epdata3[4]

epmode0pos_n3= epdata3[7]
epmode1pos_n3 = epdata3[8]
epmode2pos_n3 = epdata3[9]
epmode3pos_n3 =epdata3[10]
epmode4pos_n3 = epdata3[11]

enmode0neg_n3= endata3[0]
enmode1neg_n3 = endata3[1]
enmode2neg_n3 = endata3[2]
enmode3neg_n3 =endata3[3]
enmode4neg_n3 = endata3[4]

enmode0pos_n3= endata3[7]
enmode1pos_n3 = endata3[8]
enmode2pos_n3 = endata3[9]
enmode3pos_n3 =endata3[10]
enmode4pos_n3 = endata3[11]




kappalist_neg = np.linspace(-0.99,-0.01, num=len(epmode0neg_n5))
kappalist_pos = np.linspace(0.01, 5, num=len(epmode0pos_n5))

kappalist_pos_log=[]

for x in kappalist_pos:
    kappalist_pos_log.append(10**(x))

rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)

fig = plt.figure(figsize=(10,8))
gs = fig.add_gridspec(2, 2, hspace=0, wspace=0,)
(ax1, ax2), (ax3, ax4) = gs.subplots(sharex='col', sharey='row')
ax1.plot(kappalist_neg, epmode0neg_n5, label='$N=5$', color='black', linewidth=2.5)
ax1.plot(kappalist_neg, epmode0neg_n4, label='$N=4$', color='black', linestyle='dashed', linewidth=2.5)
ax1.plot(kappalist_neg, epmode0neg_n3, label='$N=3$', color='black', linestyle='dotted', linewidth=2.5)
#ax1.plot(kappalist_neg, epmode4neg, label='$m_4$', color='black', linestyle='dotted', linewidth=2.5)
#ax1.plot(kappalist_neg, epmode6neg, label='$m_6$', color='grey', linestyle='dotted', linewidth=2.5)
ax1.tick_params(axis='y', width=1, labelsize=20)
ax1.legend(loc = 'best', fontsize=20)
ax1.set_ylabel('$E^{P}/E$', fontsize=22)
ax3.set_xlabel('Coupling strength / $\kappa$', fontsize=22)
ax3.set_ylabel('$E^{N}/E$', fontsize=22)
ax4.set_xlabel('Coupling strength / $\kappa$', fontsize=22)
ax2.plot(kappalist_pos, epmode0pos_n5, label='$m_0, N=5$', color='black', linewidth=2.5)
ax2.plot(kappalist_pos, epmode0pos_n4, label='$m_0, N=4$', color='black', linestyle='dashed', linewidth=2.5)
ax2.plot(kappalist_pos, epmode0pos_n3, label='$m_0, N=3$', color='black', linestyle='dotted', linewidth=2.5)
#ax2.plot(kappalist_pos, epmode4pos, label='$m_4$', color='black', linestyle='dotted', linewidth=2.5)
#ax2.plot(kappalist_pos, epmode6pos, label='$m_6$', color='grey', linestyle='dotted', linewidth=2.5)
ax2.set_xticks([1,2,3,4,5], labels=['$1$', '$10$', '$10^2$', '$10^3$', '$10^4$'])
ax2.tick_params(axis='x', width=1, labelsize=20)
ax3.tick_params(axis='y', width=1, labelsize=20)

ax3.plot(kappalist_neg, enmode0neg_n5, label='$m_0, N=5$', color='black', linewidth=2.5)
ax3.plot(kappalist_neg, enmode0neg_n4, label='$m_0, N=4$', color='black', linestyle='dashed', linewidth=2.5)
ax3.plot(kappalist_neg, enmode0neg_n3, label='$m_0, N=3$', color='black', linestyle='dotted', linewidth=2.5)
#ax3.plot(kappalist_neg, enmode4neg, label='$m_4$', color='black', linestyle='dotted', linewidth=2.5)
#ax3.plot(kappalist_neg, enmode6neg, label='$m_6$', color='grey', linestyle='dotted', linewidth=2.5)
ax3.set_xticks([-1,-0.75,-0.5,-0.25,0])
ax3.tick_params(axis='x', width=1, labelsize=20)
ax4.plot(kappalist_pos, enmode0pos_n5, label='$m_0, N=5$', color='black', linewidth=2.5)
ax4.plot(kappalist_pos, enmode0pos_n4, label='$m_0, N=4$', color='black', linestyle='dashed', linewidth=2.5)
ax4.plot(kappalist_pos, enmode0pos_n3, label='$m_0, N=3$', color='black', linestyle='dotted', linewidth=2.5)
#ax4.plot(kappalist_pos, enmode4pos, label='$m_4$', color='black', linestyle='dotted', linewidth=2.5)
#ax4.plot(kappalist_pos, epmode6pos, label='$m_6$', color='grey', linestyle='dotted', linewidth=2.5)
ax4.tick_params(axis='x', width=1, labelsize=20)

fig.savefig('ferm_spin_nvaried_m0_efrac.pdf')

# %%
fig = plt.figure(figsize=(10,8))
gs = fig.add_gridspec(2, 2, hspace=0, wspace=0,)
(ax1, ax2), (ax3, ax4) = gs.subplots(sharex='col', sharey='row')
ax1.plot(kappalist_neg, epmode2neg_n5, label='$N=5$', color='black', linewidth=2.5)
ax1.plot(kappalist_neg, epmode2neg_n4, label='$N=4$', color='black', linestyle='dashed', linewidth=2.5)
ax1.plot(kappalist_neg, epmode2neg_n3, label='$N=3$', color='black', linestyle='dotted', linewidth=2.5)
#ax1.plot(kappalist_neg, epmode4neg, label='$m_4$', color='black', linestyle='dotted', linewidth=2.5)
#ax1.plot(kappalist_neg, epmode6neg, label='$m_6$', color='grey', linestyle='dotted', linewidth=2.5)
ax1.tick_params(axis='y', width=1, labelsize=20)
ax1.legend(loc = 'best', fontsize=20)
ax1.set_ylabel('$E^{P}/E$', fontsize=22)
ax3.set_xlabel('Coupling strength / $\kappa$', fontsize=22)
ax3.set_ylabel('$E^{N}/E$', fontsize=22)
ax4.set_xlabel('Coupling strength / $\kappa$', fontsize=22)
ax2.plot(kappalist_pos, epmode2pos_n5, label='$m_2, N=5$', color='black', linewidth=2.5)
ax2.plot(kappalist_pos, epmode2pos_n4, label='$m_2, N=4$', color='black', linestyle='dashed', linewidth=2.5)
ax2.plot(kappalist_pos, epmode2pos_n3, label='$m_2, N=3$', color='black', linestyle='dotted', linewidth=2.5)
#ax2.plot(kappalist_pos, epmode4pos, label='$m_4$', color='black', linestyle='dotted', linewidth=2.5)
#ax2.plot(kappalist_pos, epmode6pos, label='$m_6$', color='grey', linestyle='dotted', linewidth=2.5)
ax2.set_xticks([1,2,3,4,5], labels=['$1$', '$10$', '$10^2$', '$10^3$', '$10^4$'])
ax2.tick_params(axis='x', width=1, labelsize=20)
ax3.tick_params(axis='y', width=1, labelsize=20)

ax3.plot(kappalist_neg, enmode2neg_n5, label='$m_2, N=5$', color='black', linewidth=2.5)
ax3.plot(kappalist_neg, enmode2neg_n4, label='$m_2, N=4$', color='black', linestyle='dashed', linewidth=2.5)
ax3.plot(kappalist_neg, enmode2neg_n3, label='$m_2, N=3$', color='black', linestyle='dotted', linewidth=2.5)
#ax3.plot(kappalist_neg, enmode4neg, label='$m_4$', color='black', linestyle='dotted', linewidth=2.5)
#ax3.plot(kappalist_neg, enmode6neg, label='$m_6$', color='grey', linestyle='dotted', linewidth=2.5)
ax3.set_xticks([-1,-0.75,-0.5,-0.25,0])
ax3.tick_params(axis='x', width=1, labelsize=20)
ax4.plot(kappalist_pos, enmode2pos_n5, label='$N=5$', color='black', linewidth=2.5)
ax4.plot(kappalist_pos, enmode2pos_n4, label='$N=4$', color='black', linestyle='dashed', linewidth=2.5)
ax4.plot(kappalist_pos, enmode2pos_n3, label='$N=3$', color='black', linestyle='dotted', linewidth=2.5)
#ax4.plot(kappalist_pos, enmode4pos, label='$m_4$', color='black', linestyle='dotted', linewidth=2.5)
#ax4.plot(kappalist_pos, epmode6pos, label='$m_6$', color='grey', linestyle='dotted', linewidth=2.5)
ax4.tick_params(axis='x', width=1, labelsize=20)

fig.savefig('ferm_spin_nvaried_m2_efrac.pdf')
